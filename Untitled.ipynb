# %%
import numpy as np

# %%
np.ones((3,3)) * np.linspace(0,1,3)
# Out:
# array([[0. , 0.5, 1. ],
#        [0. , 0.5, 1. ],
#        [0. , 0.5, 1. ]])

# %%
a = np.array([0,1,2,3,5,7,11])
print(a[a > 3])
# Out:
# [ 5  7 11]
