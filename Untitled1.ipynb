# %%
import pandas as pd
from sklearn import linear_model
import numpy as np

# %%
print numpy.__path__
# Out:
#   File "C:\Users\eregn\AppData\Local\Temp\ipykernel_8752\336730439.py", line 1
#     print numpy.__path__
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(numpy.__path__)?
